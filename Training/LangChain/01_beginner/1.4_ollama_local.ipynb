# %%
import os
from langchain_ollama import ChatOllama
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
llm = ChatOllama(
    model=os.getenv("OLLAMA_MODEL","llama3.2"),
    base_url=os.getenv("OLLAMA_BASE_URL","http://ollama:11434"),
    temperature=0
)
response = llm.invoke("what is local Ai development?")
print(response.content)
# Out:
# Local AI development refers to the process of developing and deploying Artificial Intelligence (AI) models, algorithms, and systems within a specific geographic region or community. This approach focuses on creating AI solutions that are tailored to the unique needs, challenges, and characteristics of a particular location.
#
# Some key aspects of local AI development include:
#
# 1. **Geographic specificity**: Local AI development involves creating AI models that are designed to address the specific problems, opportunities, and constraints of a particular region or community.
# 2. **Domain expertise**: Local AI developers often have in-depth knowledge of the local domain, industry, or sector, which enables them to create more effective and relevant AI solutions.
# 3. **Data availability**: Local AI development typically relies on data that is specific to the region or community, such as geospatial data, sensor data, or social media data.
# 4. **Regulatory compliance**: Local AI development must comply with local regulations, laws, and standards related to data protection, privacy, and security.
#
# Benefits of local AI development include:
#
# 1. **Improved relevance**: Local AI solutions are more likely to be relevant to the specific needs and challenges of a region or community.
# 2. **Increased effectiveness**: By leveraging domain-specific knowledge and data, local AI solutions can be more effective in addressing real-world problems.
# 3. **Enhanced collaboration**: Local AI development fosters collaboration between developers, researchers, policymakers, and stakeholders from the local community.
# 4. **Job creation and economic growth**: Local AI development can create new job opportunities and stimulate economic growth by leveraging local talent and resources.
#
# Examples of local AI applications include:
#
# 1. **Smart city initiatives**: Using AI to optimize traffic flow, energy management, and public services in urban areas.
# 2. **Agricultural AI**: Developing AI-powered solutions for precision farming, crop monitoring, and yield prediction in rural regions.
# 3. **Healthcare AI**: Creating AI-driven diagnostic tools, personalized medicine, and patient engagement platforms tailored to local healthcare needs.
# 4. **Environmental monitoring**: Using AI to analyze satellite data, sensor readings, and other environmental data to monitor climate change, deforestation, or water quality.
#
# By focusing on local AI development, communities can create more effective, relevant, and sustainable AI solutions that address their unique challenges and opportunities.
