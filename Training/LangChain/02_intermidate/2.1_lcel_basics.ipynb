# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# %%
#setup components
prompt = ChatPromptTemplate.from_template("tell me fun fact about {topic}. in 50 words")
model = ChatOpenAI(model="gpt-4o")
parser = StrOutputParser()

#langchain puip
chain = prompt | model | parser

result = chain.invoke({"topic":"Ice Cream"})
print(result)
# Out:
# Ice cream was once a luxury reserved for the elite. In the 18th century, U.S. President Thomas Jefferson famously served an elaborate 18-step ice cream recipe at the White House. Today, it's a beloved treat worldwide, with unique flavors like garlic and squid ink pushing the boundaries of tradition.
