# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
response = llm.invoke("What are the key components of a RAG system?")
print(response.content)
# Out:
# A RAG (Red, Amber, Green) system is a visual management tool used to indicate the status of a project, task, or performance metric. The key components of a RAG system include:
#
# 1. **Color Coding**:
#    - **Red**: Indicates a critical issue or significant risk that requires immediate attention. It often signifies that a project is behind schedule, over budget, or not meeting key performance indicators (KPIs).
#    - **Amber (or Yellow)**: Represents a warning or caution. It suggests that there are potential issues that could escalate if not addressed, but the situation is not yet critical.
#    - **Green**: Signifies that everything is on track. The project or task is progressing as planned, meeting deadlines, and staying within budget.
#
# 2. **Criteria for Assessment**:
#    - Clear definitions and criteria for what constitutes Red, Amber, and Green statuses. This may include specific metrics, thresholds, or performance indicators that help determine the color coding.
#
# 3. **Regular Updates**:
#    - A schedule for regularly updating the RAG status, ensuring that stakeholders have the most current information. This could be weekly, monthly, or at key project milestones.
#
# 4. **Reporting Mechanism**:
#    - A system for reporting and communicating the RAG status to stakeholders. This could be through dashboards, reports, or meetings, ensuring transparency and accountability.
#
# 5. **Action Plans**:
#    - For Red and Amber statuses, there should be defined action plans or mitigation strategies to address the issues. This includes assigning responsibilities and timelines for resolution.
#
# 6. **Stakeholder Engagement**:
#    - Involvement of relevant stakeholders in the assessment process to ensure that the RAG status reflects a comprehensive view of the project or task.
#
# 7. **Documentation**:
#    - Keeping records of RAG assessments over time to track progress, identify trends, and learn from past issues.
#
# 8. **Integration with Other Tools**:
#    - The RAG system can be integrated with other project management tools and methodologies to enhance its effectiveness and provide a holistic view of project health.
#
# By effectively utilizing these components, organizations can enhance their project management processes, improve communication, and facilitate timely decision-making.
